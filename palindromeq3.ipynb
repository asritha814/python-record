# %% [markdown]
# <a href="https://colab.research.google.com/github/asritha814/python-record/blob/main/palindromeq3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q3=write a python program to check if a number is a palindrome and count the frequency of each height
number = input("Enter a number: ")
if number == number[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
for i in range(10):
    count = number.count(str(i))
    if count > 0:
        print(f"{i} appears {count} times")
# Out:
# Enter a number: 12321
# Palindrome
# 1 appears 2 times
# 2 appears 2 times
# 3 appears 1 times
